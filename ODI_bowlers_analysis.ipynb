# %% [markdown]
# <a href="https://colab.research.google.com/github/MdFaisalHasan/ODI_bowlers_analysis/blob/main/ODI_bowlers_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### 1. import the ODI_cricker.xlsx file bowler sheet in your notebook

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/MdFaisalHasan/ODI_bowlers_analysis/main/ODI_cricket_bowler.csv')

# %% [markdown]
# ###### Tried many times to import the xlsx file from github and work on it. But 'BadZipFile: File is not a zip file' error was showing again and again. So, converted the sheet to csv and worked on that.

# %% [markdown]
# ###### 2. Display the first 10 rows of the dataframe

# %%
display(df.head(10))
# Out:
#                          Player       Span  Mat  Inns  Balls   Runs  Wkts  \
# 0  M Muralitharan (Asia/ICC/SL)  1993-2011  350   341  18811  12326   534
# 1             Wasim Akram (PAK)  1984-2003  356   351  18186  11812   502
# 2            Waqar Younis (PAK)  1989-2003  262   258  12698   9919   416
# 3          WPUJC Vaas (Asia/SL)  1994-2008  322   320  15775  11014   400
# 4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   372  17670  13632   395
# 5       SM Pollock (Afr/ICC/SA)  1996-2008  303   297  15712   9631   393
# 6          GD McGrath (AUS/ICC)  1993-2007  250   248  12970   8391   381
# 7                   B Lee (AUS)  2000-2012  221   217  11185   8877   380
# 8               SL Malinga (SL)  2004-2019  226   220  10936   9760   338
# 9         A Kumble (Asia/INDIA)  1990-2007  271   265  14496  10412   337
#
#      Ave  Econ    SR   4   5
# 0  23.08  3.93  35.2  15  10
# 1  23.52  3.89  36.2  17   6
# 2  23.84  4.68  30.5  14  13
# 3  27.53  4.18  39.4   9   4
# ...

# %% [markdown]
# ###### 3. Create a markdown cell and explain the meaning of each column

# %%
print(df.columns)
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'Balls', 'Runs', 'Wkts', 'Ave', 'Econ',
#        'SR', '4', '5'],
#       dtype='object')

# %% [markdown]
# ###### Player- Player name and county/team
# <br>Span- Playing span
# <br>Mat- Matches played
# <br>Inns- Innings bowled
# <br>Balls- Balls bowled
# <br>Runs-Runs conceded
# <br>Wkts- Wickets taken
# <br>Ave- Bowling average
# <br>Econ- Economy rate
# <br>SR- Bowling strike rate
# <br>4- four wkts in an inns
# <br>5- five wkts in an inns

# %% [markdown]
# ###### 4. find the number of rows and columns in the dataframe

# %%
print('number of rows=',df.shape[0])
print('number of rows=',df.shape[1])
# Out:
# number of rows= 77
# number of rows= 12

# %% [markdown]
# ###### 5. find the data statistics and check for the data types

# %%
display(df.describe())
display(df.info())
# Out:
#               Mat        Inns         Balls          Runs        Wkts  \
# count   77.000000   77.000000     77.000000     77.000000   77.000000
# mean   194.402597  181.194805   8839.402597   6671.714286  233.805195
# std     82.485606   67.958393   3316.055457   2245.839029   84.406603
# min     80.000000   76.000000   4074.000000   2821.000000  151.000000
# 25%    136.000000  128.000000   6182.000000   5058.000000  173.000000
# 50%    170.000000  164.000000   8054.000000   6192.000000  199.000000
# 75%    227.000000  218.000000  10750.000000   8021.000000  272.000000
# max    463.000000  372.000000  18811.000000  13632.000000  534.000000
#
#              Ave       Econ         SR          4          5
# count  77.000000  77.000000  77.000000  77.000000  77.000000
# mean   28.958052   4.596753  37.909091   6.350649   2.870130
# std     4.826768   0.515814   6.060901   3.556929   2.530606
# min    18.680000   3.300000  26.100000   1.000000   0.000000
# ...

# %% [markdown]
# ###### 6. Are there any missing values present in the dataset?

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  77 non-null     object
#  1   Span    77 non-null     object
#  2   Mat     77 non-null     int64
#  3   Inns    77 non-null     int64
#  4   Balls   77 non-null     int64
#  5   Runs    77 non-null     int64
#  6   Wkts    77 non-null     int64
#  7   Ave     77 non-null     float64
#  8   Econ    77 non-null     float64
#  9   SR      77 non-null     float64
#  10  4       77 non-null     int64
#  11  5       77 non-null     int64
# dtypes: float64(3), int64(7), object(2)
# memory usage: 7.3+ KB
# None

# %% [markdown]
# ###### From above info, as there is no null value, we can say there is no missing value.

# %% [markdown]
# ###### 7. Renaming the column names appropriately

# %%
print(df.columns)
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'Balls', 'Runs', 'Wkts', 'Ave', 'Econ',
#        'SR', '4', '5'],
#       dtype='object')

# %%
df = df.rename(columns={'Span':'Playing_span',
                        'Mat':'Matches_played',
                        'Inns':'Innings_bowled',
                        'Balls':'Balls_bowled',
                        'Runs':'Runs_conceded',
                        'Wkts':'Wickets_taken',
                        'Ave':'Bowling_average',
                        'Econ':'Economy_rate',
                        'SR':'Bowling_strike_rate',
                        '4':'Four_wkts_in_an_inns',
                        '5':'Five_wkts_in_an_inns'})

# %%
df.head()
# Out:
#                          Player Playing_span  Matches_played  Innings_bowled  \
# 0  M Muralitharan (Asia/ICC/SL)    1993-2011             350             341
# 1             Wasim Akram (PAK)    1984-2003             356             351
# 2            Waqar Younis (PAK)    1989-2003             262             258
# 3          WPUJC Vaas (Asia/SL)    1994-2008             322             320
# 4  Shahid Afridi (Asia/ICC/PAK)    1996-2015             398             372
#
#    Balls_bowled  Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 0         18811          12326            534            23.08          3.93
# 1         18186          11812            502            23.52          3.89
# 2         12698           9919            416            23.84          4.68
# 3         15775          11014            400            27.53          4.18
# 4         17670          13632            395            34.51          4.62
#
# ...

# %% [markdown]
# ###### 8. How many players played for ICC?

# %%
def icc_check(x):
    if 'ICC' in x:
        return 'Yes'
    else:
        return 'No'

# %%
df['played_for_ICC'] = df['Player'].apply(icc_check)

# %%
display(df.head())
# Out:
#                          Player Playing_span  Matches_played  Innings_bowled  \
# 0  M Muralitharan (Asia/ICC/SL)    1993-2011             350             341
# 1             Wasim Akram (PAK)    1984-2003             356             351
# 2            Waqar Younis (PAK)    1989-2003             262             258
# 3          WPUJC Vaas (Asia/SL)    1994-2008             322             320
# 4  Shahid Afridi (Asia/ICC/PAK)    1996-2015             398             372
#
#    Balls_bowled  Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 0         18811          12326            534            23.08          3.93
# 1         18186          11812            502            23.52          3.89
# 2         12698           9919            416            23.84          4.68
# 3         15775          11014            400            27.53          4.18
# 4         17670          13632            395            34.51          4.62
#
# ...

# %%
print(df['played_for_ICC'].value_counts())
# Out:
# No     64
# Yes    13
# Name: played_for_ICC, dtype: int64

# %% [markdown]
# ###### 13 players played for ICC.

# %% [markdown]
# ###### 9. How many different countries are present in this dataset?

# %%
df[['Player_Name', 'Country']] = df['Player'].str.split('(', expand=True)

# %%
display(df.head())
# Out:
#                          Player Playing_span  Matches_played  Innings_bowled  \
# 0  M Muralitharan (Asia/ICC/SL)    1993-2011             350             341
# 1             Wasim Akram (PAK)    1984-2003             356             351
# 2            Waqar Younis (PAK)    1989-2003             262             258
# 3          WPUJC Vaas (Asia/SL)    1994-2008             322             320
# 4  Shahid Afridi (Asia/ICC/PAK)    1996-2015             398             372
#
#    Balls_bowled  Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 0         18811          12326            534            23.08          3.93
# 1         18186          11812            502            23.52          3.89
# 2         12698           9919            416            23.84          4.68
# 3         15775          11014            400            27.53          4.18
# 4         17670          13632            395            34.51          4.62
#
# ...

# %%
df.drop('Player', axis=1, inplace=True)

# %%
display(df.head())
# Out:
#   Playing_span  Matches_played  Innings_bowled  Balls_bowled  Runs_conceded  \
# 0    1993-2011             350             341         18811          12326
# 1    1984-2003             356             351         18186          11812
# 2    1989-2003             262             258         12698           9919
# 3    1994-2008             322             320         15775          11014
# 4    1996-2015             398             372         17670          13632
#
#    Wickets_taken  Bowling_average  Economy_rate  Bowling_strike_rate  \
# 0            534            23.08          3.93                 35.2
# 1            502            23.52          3.89                 36.2
# 2            416            23.84          4.68                 30.5
# 3            400            27.53          4.18                 39.4
# 4            395            34.51          4.62                 44.7
#
#    Four_wkts_in_an_inns  Five_wkts_in_an_inns played_for_ICC      Player_Name  \
# ...

# %%
df['Country'] = df['Country'].str.replace(")", "")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.

# %%
display(df.head())
# Out:
#   Playing_span  Matches_played  Innings_bowled  Balls_bowled  Runs_conceded  \
# 0    1993-2011             350             341         18811          12326
# 1    1984-2003             356             351         18186          11812
# 2    1989-2003             262             258         12698           9919
# 3    1994-2008             322             320         15775          11014
# 4    1996-2015             398             372         17670          13632
#
#    Wickets_taken  Bowling_average  Economy_rate  Bowling_strike_rate  \
# 0            534            23.08          3.93                 35.2
# 1            502            23.52          3.89                 36.2
# 2            416            23.84          4.68                 30.5
# 3            400            27.53          4.18                 39.4
# 4            395            34.51          4.62                 44.7
#
#    Four_wkts_in_an_inns  Five_wkts_in_an_inns played_for_ICC      Player_Name  \
# ...

# %%
print(df['Country'].value_counts())
# Out:
# INDIA           9
# PAK             9
# AUS             8
# NZ              6
# SL              5
# WI              5
# Asia/INDIA      4
# ENG             4
# Asia/SL         3
# SA              3
# Afr/ICC/SA      2
# AUS/ICC         2
# Asia/ICC/PAK    2
# ENG/ICC         2
# ICC/NZ          2
# BAN             2
# Afr/SA          2
# ICC/WI          1
# Asia/ICC/SL     1
# Afr/ZIM         1
# ICC/SA          1
# Asia/PAK        1
# Asia/BAN        1
# AFG             1
# Name: Country, dtype: int64

# %%
def Asia_check(x):
    if 'Asia' in x:
        return 'Yes'
    else:
        return 'No'

# %%
def Afr_check(x):
    if 'Afr' in x:
        return 'Yes'
    else:
        return 'No'

# %%
df['played_for_Asia'] = df['Country'].apply(Asia_check)
df['played_for_Afr'] = df['Country'].apply(Afr_check)

# %%
display(df.head())
# Out:
#   Playing_span  Matches_played  Innings_bowled  Balls_bowled  Runs_conceded  \
# 0    1993-2011             350             341         18811          12326
# 1    1984-2003             356             351         18186          11812
# 2    1989-2003             262             258         12698           9919
# 3    1994-2008             322             320         15775          11014
# 4    1996-2015             398             372         17670          13632
#
#    Wickets_taken  Bowling_average  Economy_rate  Bowling_strike_rate  \
# 0            534            23.08          3.93                 35.2
# 1            502            23.52          3.89                 36.2
# 2            416            23.84          4.68                 30.5
# 3            400            27.53          4.18                 39.4
# 4            395            34.51          4.62                 44.7
#
#    Four_wkts_in_an_inns  Five_wkts_in_an_inns played_for_ICC      Player_Name  \
# ...

# %%
display(df.columns)
# Out:
# Index(['Playing_span', 'Matches_played', 'Innings_bowled', 'Balls_bowled',
#        'Runs_conceded', 'Wickets_taken', 'Bowling_average', 'Economy_rate',
#        'Bowling_strike_rate', 'Four_wkts_in_an_inns', 'Five_wkts_in_an_inns',
#        'played_for_ICC', 'Player_Name', 'Country', 'played_for_Asia',
#        'played_for_Afr'],
#       dtype='object')

# %%
new_col_sequence = ['Player_Name', 'Country', 'Playing_span', 'Matches_played', 'Innings_bowled', 'Balls_bowled',
       'Runs_conceded', 'Wickets_taken', 'Bowling_average', 'Economy_rate',
       'Bowling_strike_rate', 'Four_wkts_in_an_inns', 'Five_wkts_in_an_inns',
       'played_for_ICC', 'played_for_Asia',
       'played_for_Afr']

# %%
display(df.head())
# Out:
#   Playing_span  Matches_played  Innings_bowled  Balls_bowled  Runs_conceded  \
# 0    1993-2011             350             341         18811          12326
# 1    1984-2003             356             351         18186          11812
# 2    1989-2003             262             258         12698           9919
# 3    1994-2008             322             320         15775          11014
# 4    1996-2015             398             372         17670          13632
#
#    Wickets_taken  Bowling_average  Economy_rate  Bowling_strike_rate  \
# 0            534            23.08          3.93                 35.2
# 1            502            23.52          3.89                 36.2
# 2            416            23.84          4.68                 30.5
# 3            400            27.53          4.18                 39.4
# 4            395            34.51          4.62                 44.7
#
#    Four_wkts_in_an_inns  Five_wkts_in_an_inns played_for_ICC      Player_Name  \
# ...

# %%
df = df[new_col_sequence]

# %%
display(df.head())
# Out:
#        Player_Name       Country Playing_span  Matches_played  Innings_bowled  \
# 0  M Muralitharan    Asia/ICC/SL    1993-2011             350             341
# 1     Wasim Akram            PAK    1984-2003             356             351
# 2    Waqar Younis            PAK    1989-2003             262             258
# 3      WPUJC Vaas        Asia/SL    1994-2008             322             320
# 4   Shahid Afridi   Asia/ICC/PAK    1996-2015             398             372
#
#    Balls_bowled  Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 0         18811          12326            534            23.08          3.93
# 1         18186          11812            502            23.52          3.89
# 2         12698           9919            416            23.84          4.68
# 3         15775          11014            400            27.53          4.18
# 4         17670          13632            395            34.51          4.62
#
# ...

# %%
print(df['Country'].value_counts())
# Out:
# INDIA           9
# PAK             9
# AUS             8
# NZ              6
# SL              5
# WI              5
# Asia/INDIA      4
# ENG             4
# Asia/SL         3
# SA              3
# Afr/ICC/SA      2
# AUS/ICC         2
# Asia/ICC/PAK    2
# ENG/ICC         2
# ICC/NZ          2
# BAN             2
# Afr/SA          2
# ICC/WI          1
# Asia/ICC/SL     1
# Afr/ZIM         1
# ICC/SA          1
# Asia/PAK        1
# Asia/BAN        1
# AFG             1
# Name: Country, dtype: int64

# %%
df['Country'] = df['Country'].str.replace('Asia','')
df['Country'] = df['Country'].str.replace('ICC','')
df['Country'] = df['Country'].str.replace('Afr','')
df['Country'] = df['Country'].str.replace('/','')

# %%
df.nunique()
# Out:
# Player_Name             77
# Country                 11
# Playing_span            66
# Matches_played          67
# Innings_bowled          68
# Balls_bowled            76
# Runs_conceded           76
# Wickets_taken           59
# Bowling_average         72
# Economy_rate            60
# Bowling_strike_rate     63
# Four_wkts_in_an_inns    15
# Five_wkts_in_an_inns    12
# played_for_ICC           2
# played_for_Asia          2
# played_for_Afr           2
# dtype: int64

# %% [markdown]
# ###### From the above list, there are 11 different countries are present in this dataset

# %% [markdown]
# ###### 10. Which player(s) had played for the longest period of time?

# %%
df['Start_year'] = df['Playing_span'].str[:4]
df['End_year'] = df['Playing_span'].str[5:]

# %%
display(df.head())
# Out:
#        Player_Name Country Playing_span  Matches_played  Innings_bowled  \
# 0  M Muralitharan       SL    1993-2011             350             341
# 1     Wasim Akram      PAK    1984-2003             356             351
# 2    Waqar Younis      PAK    1989-2003             262             258
# 3      WPUJC Vaas       SL    1994-2008             322             320
# 4   Shahid Afridi      PAK    1996-2015             398             372
#
#    Balls_bowled  Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 0         18811          12326            534            23.08          3.93
# 1         18186          11812            502            23.52          3.89
# 2         12698           9919            416            23.84          4.68
# 3         15775          11014            400            27.53          4.18
# 4         17670          13632            395            34.51          4.62
#
#    Bowling_strike_rate  Four_wkts_in_an_inns  Five_wkts_in_an_inns  \
# ...

# %%
df=df.drop('Playing_span', axis=1)

# %%
df.head()
# Out:
#        Player_Name Country  Matches_played  Innings_bowled  Balls_bowled  \
# 0  M Muralitharan       SL             350             341         18811
# 1     Wasim Akram      PAK             356             351         18186
# 2    Waqar Younis      PAK             262             258         12698
# 3      WPUJC Vaas       SL             322             320         15775
# 4   Shahid Afridi      PAK             398             372         17670
#
#    Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 0          12326            534            23.08          3.93
# 1          11812            502            23.52          3.89
# 2           9919            416            23.84          4.68
# 3          11014            400            27.53          4.18
# 4          13632            395            34.51          4.62
#
#    Bowling_strike_rate  Four_wkts_in_an_inns  Five_wkts_in_an_inns  \
# 0                 35.2                    15                    10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Player_Name           77 non-null     object
#  1   Country               77 non-null     object
#  2   Matches_played        77 non-null     int64
#  3   Innings_bowled        77 non-null     int64
#  4   Balls_bowled          77 non-null     int64
#  5   Runs_conceded         77 non-null     int64
#  6   Wickets_taken         77 non-null     int64
#  7   Bowling_average       77 non-null     float64
#  8   Economy_rate          77 non-null     float64
#  9   Bowling_strike_rate   77 non-null     float64
#  10  Four_wkts_in_an_inns  77 non-null     int64
#  11  Five_wkts_in_an_inns  77 non-null     int64
#  12  played_for_ICC        77 non-null     object
#  13  played_for_Asia       77 non-null     object
#  14  played_for_Afr        77 non-null     object
# ...

# %%
df['Start_year'] = df['Start_year'].astype('int') 
df['End_year'] = df['End_year'].astype('int')

# %%
df.head()
# Out:
#        Player_Name Country  Matches_played  Innings_bowled  Balls_bowled  \
# 0  M Muralitharan       SL             350             341         18811
# 1     Wasim Akram      PAK             356             351         18186
# 2    Waqar Younis      PAK             262             258         12698
# 3      WPUJC Vaas       SL             322             320         15775
# 4   Shahid Afridi      PAK             398             372         17670
#
#    Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 0          12326            534            23.08          3.93
# 1          11812            502            23.52          3.89
# 2           9919            416            23.84          4.68
# 3          11014            400            27.53          4.18
# 4          13632            395            34.51          4.62
#
#    Bowling_strike_rate  Four_wkts_in_an_inns  Five_wkts_in_an_inns  \
# 0                 35.2                    15                    10
# ...

# %%
df['Years_played'] = df['End_year'] - df['Start_year']+1

# %%
df.head()
# Out:
#        Player_Name Country  Matches_played  Innings_bowled  Balls_bowled  \
# 0  M Muralitharan       SL             350             341         18811
# 1     Wasim Akram      PAK             356             351         18186
# 2    Waqar Younis      PAK             262             258         12698
# 3      WPUJC Vaas       SL             322             320         15775
# 4   Shahid Afridi      PAK             398             372         17670
#
#    Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 0          12326            534            23.08          3.93
# 1          11812            502            23.52          3.89
# 2           9919            416            23.84          4.68
# 3          11014            400            27.53          4.18
# 4          13632            395            34.51          4.62
#
#    Bowling_strike_rate  Four_wkts_in_an_inns  Five_wkts_in_an_inns  \
# 0                 35.2                    15                    10
# ...

# %%
df = df.drop(['Start_year','End_year'], axis=1)

# %%
df.head()
# Out:
#        Player_Name Country  Matches_played  Innings_bowled  Balls_bowled  \
# 0  M Muralitharan       SL             350             341         18811
# 1     Wasim Akram      PAK             356             351         18186
# 2    Waqar Younis      PAK             262             258         12698
# 3      WPUJC Vaas       SL             322             320         15775
# 4   Shahid Afridi      PAK             398             372         17670
#
#    Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 0          12326            534            23.08          3.93
# 1          11812            502            23.52          3.89
# 2           9919            416            23.84          4.68
# 3          11014            400            27.53          4.18
# 4          13632            395            34.51          4.62
#
#    Bowling_strike_rate  Four_wkts_in_an_inns  Five_wkts_in_an_inns  \
# 0                 35.2                    15                    10
# ...

# %%
df.sort_values(by='Years_played', ascending = False).head()
# Out:
#        Player_Name Country  Matches_played  Innings_bowled  Balls_bowled  \
# 72   SR Tendulkar    INDIA             463             270          8054
# 10  ST Jayasuriya       SL             445             368         14874
# 66   Shoaib Malik      PAK             287             217          7958
# 62       CH Gayle       WI             301             199          7424
# 4   Shahid Afridi      PAK             398             372         17670
#
#     Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 72           6850            154            44.48          5.10
# 10          11871            323            36.75          4.78
# 66           6192            158            39.18          4.66
# 62           5926            167            35.48          4.78
# 4           13632            395            34.51          4.62
#
#     Bowling_strike_rate  Four_wkts_in_an_inns  Five_wkts_in_an_inns  \
# 72                 52.2                     4                     2
# ...

# %% [markdown]
# ###### From the sorted list above SR Tendulkar had played for the longest period of time, 24 years.

# %% [markdown]
# ###### 11. Which player(s) had played for the shortest period of time?

# %%
df.sort_values(by='Years_played').head()
# Out:
#      Player_Name Country  Matches_played  Innings_bowled  Balls_bowled  \
# 40   BKV Prasad    INDIA             161             160          8129
# 74  Rashid Khan      AFG              80              76          4074
# 73   BAW Mendis       SL              87              84          4154
# 49  Saeed Ajmal      PAK             113             112          6000
# 44   L Klusener       SA             171             164          7336
#
#     Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 40           6332            196            32.30          4.67
# 74           2821            151            18.68          4.15
# 73           3324            152            21.86          4.80
# 49           4182            184            22.72          4.18
# 44           5751            192            29.95          4.70
#
#     Bowling_strike_rate  Four_wkts_in_an_inns  Five_wkts_in_an_inns  \
# 40                 41.4                     3                     1
# ...

# %% [markdown]
# ###### From the sorted list above BKV Prasad	had played for the shortest period of time, 8 years.

# %% [markdown]
# ###### 12. How many Australian Bowlers are present in this dataset?

# %%
print(df['Country'].value_counts())
# Out:
# INDIA    13
# PAK      12
# AUS      10
# SL        9
# SA        8
# NZ        8
# ENG       6
# WI        6
# BAN       3
# ZIM       1
# AFG       1
# Name: Country, dtype: int64

# %% [markdown]
# ###### 10 Australian Bowlers are present in this dataset.

# %% [markdown]
# ###### 13. Is there any Bangladeshi player present in this dataset?
# <br>Yes, 3 Bangladeshi players are present in this dataset.

# %% [markdown]
# ###### 14. Which player had the lowest economy rate?

# %%
df.sort_values(by='Economy_rate').head()
# Out:
#      Player_Name Country  Matches_played  Innings_bowled  Balls_bowled  \
# 65    RJ Hadlee       NZ             115             112          6182
# 32  CEL Ambrose       WI             176             175          9353
# 67  MD Marshall       WI             136             134          7175
# 5    SM Pollock       SA             303             297         15712
# 25  N Kapil Dev    INDIA             225             221         11202
#
#     Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 65           3407            158            21.56          3.30
# 32           5429            225            24.12          3.48
# 67           4233            157            26.96          3.53
# 5            9631            393            24.50          3.67
# 25           6945            253            27.45          3.71
#
#     Bowling_strike_rate  Four_wkts_in_an_inns  Five_wkts_in_an_inns  \
# 65                 39.1                     1                     5
# ...

# %% [markdown]
# ###### RJ Hadlee had the lowest economy rate, 3.30.

# %% [markdown]
# ###### 15. Which player had the lowest strike rate?

# %%
df.sort_values(by='Bowling_strike_rate').head()
# Out:
#      Player_Name Country  Matches_played  Innings_bowled  Balls_bowled  \
# 41     MA Starc      AUS              99              99          5099
# 74  Rashid Khan      AFG              80              76          4074
# 73   BAW Mendis       SL              87              84          4154
# 7         B Lee      AUS             221             217         11185
# 60     TA Boult       NZ              93              93          5117
#
#     Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 41           4379            195            22.45          5.15
# 74           2821            151            18.68          4.15
# 73           3324            152            21.86          4.80
# 7            8877            380            23.36          4.76
# 60           4261            169            25.21          4.99
#
#     Bowling_strike_rate  Four_wkts_in_an_inns  Five_wkts_in_an_inns  \
# 41                 26.1                    11                     8
# ...

# %% [markdown]
# ###### MA Starc had the lowest strike rate, 26.1.

# %% [markdown]
# ###### 16. Which player had the lowest bowling average?

# %%
df.sort_values(by='Bowling_average').head()
# Out:
#          Player_Name Country  Matches_played  Innings_bowled  Balls_bowled  \
# 74      Rashid Khan      AFG              80              76          4074
# 65        RJ Hadlee       NZ             115             112          6182
# 19        AA Donald       SA             164             162          8561
# 14  Saqlain Mushtaq      PAK             169             165          8770
# 73       BAW Mendis       SL              87              84          4154
#
#     Runs_conceded  Wickets_taken  Bowling_average  Economy_rate  \
# 74           2821            151            18.68          4.15
# 65           3407            158            21.56          3.30
# 19           5926            272            21.78          4.15
# 14           6275            288            21.78          4.29
# 73           3324            152            21.86          4.80
#
#     Bowling_strike_rate  Four_wkts_in_an_inns  Five_wkts_in_an_inns  \
# ...

# %% [markdown]
# ###### Rashid Khan had the lowest bowling average, 18.68.

# %% [markdown]
# ###### 17. Remove Unnecessary columns if needed

# %%
display(df.columns)
# Out:
# Index(['Player_Name', 'Country', 'Matches_played', 'Innings_bowled',
#        'Balls_bowled', 'Runs_conceded', 'Wickets_taken', 'Bowling_average',
#        'Economy_rate', 'Bowling_strike_rate', 'Four_wkts_in_an_inns',
#        'Five_wkts_in_an_inns', 'played_for_ICC', 'played_for_Asia',
#        'played_for_Afr', 'Years_played'],
#       dtype='object')

# %% [markdown]
# ###### Unnecessary columns were removed during the operations, so which columns are left, all seems to be necessary.
